# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load Excel dataset
dfA = pd.read_excel("~/Downloads/AIOE_DataAppendix.xlsx", sheet_name="Appendix A")
dfB = pd.read_excel("~/Downloads/AIOE_DataAppendix.xlsx", sheet_name="Appendix B")
dfC = pd.read_excel("~/Downloads/AIOE_DataAppendix.xlsx", sheet_name="Appendix C")
dfD = pd.read_excel("~/Downloads/AIOE_DataAppendix.xlsx", sheet_name="Appendix D")
dfE = pd.read_excel("~/Downloads/AIOE_DataAppendix.xlsx", sheet_name="Appendix E")

# Basic inspection
print(dfA.shape)
dfA.head()

# Dataset info
dfA.info()

# Summary statistics
dfA.describe()

# Missing values
print(dfA.isnull().sum())

dfA.hist(figsize=(12,8))
plt.show()
# Out:
# (774, 3)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 774 entries, 0 to 773
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   SOC Code          774 non-null    object
#  1   Occupation Title  774 non-null    object
#  2   AIOE              774 non-null    float64
# dtypes: float64(1), object(2)
# memory usage: 18.3+ KB
# SOC Code            0
# Occupation Title    0
# AIOE                0
# dtype: int64

# %%
dfB = pd.read_excel("~/Downloads/AIOE_DataAppendix.xlsx", sheet_name="Appendix B")


# Basic inspection
print(dfB.shape)
dfB.head()

# Dataset info
dfB.info()

# Summary statistics
dfB.describe()

# Missing values
print(dfB.isnull().sum())

dfB.hist(figsize=(12,8))
plt.show()
# Out:
# (250, 3)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   NAICS           250 non-null    int64
#  1   Industry Title  250 non-null    object
#  2   AIIE            250 non-null    float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 6.0+ KB
# NAICS             0
# Industry Title    0
# AIIE              0
# dtype: int64

# %%
dfC = pd.read_excel("~/Downloads/AIOE_DataAppendix.xlsx", sheet_name="Appendix C")


# Basic inspection
print(dfC.shape)
dfC.head()

# Dataset info
dfC.info()

# Summary statistics
dfC.describe()

# Missing values
print(dfC.isnull().sum())

dfC.hist(figsize=(12,8))
plt.show()
# Out:
# (3271, 3)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3271 entries, 0 to 3270
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   FIPS Code        3271 non-null   int64
#  1   Geographic Area  3271 non-null   object
#  2   AIGE             3271 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 76.8+ KB
# FIPS Code          0
# Geographic Area    0
# AIGE               0
# dtype: int64

# %%
dfD = pd.read_excel("~/Downloads/AIOE_DataAppendix.xlsx", sheet_name="Appendix D")


# Basic inspection
print(dfD.shape)
dfD.head()

# Dataset info
dfD.info()

# Summary statistics
dfD.describe()

# Missing values
print(dfD.isnull().sum())

dfD.hist(figsize=(12,8))
plt.show()
# Out:
# (52, 11)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 11 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Unnamed: 0                      52 non-null     object
#  1   Abstract Strategy Games         52 non-null     float64
#  2   Real-Time Video Games           52 non-null     float64
#  3   Image Recognition               52 non-null     float64
#  4   Visual Question Answering       52 non-null     float64
#  5   Generating Images               52 non-null     float64
#  6   Reading Comprehension           52 non-null     float64
#  7   Language Modeling               52 non-null     float64
#  8   Translation                     52 non-null     float64
#  9   Speech Recognition              52 non-null     float64
#  10  Instrumental Track Recognition  52 non-null     float64
# dtypes: float64(10), object(1)
# memory usage: 4.6+ KB
# ...

# %%
dfE = pd.read_excel("~/Downloads/AIOE_DataAppendix.xlsx", sheet_name="Appendix E")


# Basic inspection
print(dfE.shape)
dfE.head()

# Dataset info
dfE.info()

# Summary statistics
dfE.describe()

# Missing values
print(dfE.isnull().sum())

dfE.hist(figsize=(12,8))
plt.show()
# Out:
# (52, 2)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 2 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   O*NET Abilities            52 non-null     object
#  1   Ability-Level AI Exposure  52 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 964.0+ bytes
# O*NET Abilities              0
# Ability-Level AI Exposure    0
# dtype: int64
